# %%
import sys

sys.path.insert(0, "../")
from modules.functions_ver2 import *

# %%
omega_arr = np.array([0, 1, 2, 3, 4])
for omega in omega_arr:
    RP_params = set_to_location(loc_params["Taman"]["faceon"], RP_params_1)[0]
    RP_params["theta_tilde"] = 0
    RP_params["omega_tilde"] = omega
    RP_inst = Precessing(RP_params)
    f_arr = np.linspace(20, RP_inst.f_cut(), 100)
    y_data = RP_inst.phi_LJ(f_arr)
    plt.plot(f_arr, y_data, label=f"$\~\Omega$ = {omega}")
plt.legend()
plt.grid()
plt.xlabel("f [Hz]")
plt.ylabel("phi_LJ")
# Out:
# Text(0, 0.5, 'phi_LJ')

# %%
omega_arr = np.array([0, 1, 2, 3, 4])
for omega in omega_arr:
    RP_params = set_to_location(loc_params["Taman"]["faceon"], RP_params_1)[0]
    RP_params["theta_tilde"] = 0
    RP_params["omega_tilde"] = omega
    RP_inst = Precessing(RP_params)
    f_arr = np.linspace(20, RP_inst.f_cut(), 100)
    y_data = RP_inst.amplitude(f_arr)
    plt.plot(f_arr, y_data, label=f"$\~\Omega$ = {omega}")
plt.legend()
plt.grid()
plt.xlabel("f [Hz]")
plt.ylabel("amplitude")
# Out:
# Text(0, 0.5, 'amplitude')

# %%
# Before commenting out the faulty condition `if np.all(np.abs(den_psi) < NEAR_ZERO_THRESHOLD)` or `if den_psi.all() == 0`
omega_arr = np.array([0, 1, 2, 3, 4])
for omega in omega_arr:
    RP_params = set_to_location(loc_params["Taman"]["faceon"], RP_params_1)[0]
    RP_params["theta_tilde"] = 0
    RP_params["omega_tilde"] = omega
    RP_inst = Precessing(RP_params)
    f_arr = np.linspace(20, RP_inst.f_cut(), 100)
    y_data = RP_inst.phase_phi_P(f_arr)
    plt.plot(f_arr, y_data, label=f"$\~\Omega$ = {omega}")
plt.legend()
plt.grid()
plt.xlabel("f [Hz]")
plt.ylabel("phase_phi_P")
# Out:
# Text(0, 0.5, 'phase_phi_P')

# %%
# After
omega_arr = np.array([0, 1, 2, 3, 4])
for omega in omega_arr:
    RP_params = set_to_location(loc_params["Taman"]["faceon"], RP_params_1)[0]
    RP_params["theta_tilde"] = 0
    RP_params["omega_tilde"] = omega
    RP_inst = Precessing(RP_params)
    f_arr = np.linspace(20, RP_inst.f_cut(), 100)
    y_data = RP_inst.phase_phi_P(f_arr)
    plt.plot(f_arr, y_data, label=f"$\~\Omega$ = {omega}")
plt.legend()
plt.grid()
plt.xlabel("f [Hz]")
plt.ylabel("phase_phi_P")
# Out:
# Text(0, 0.5, 'phase_phi_P')

# %%
omega_arr = np.array([0, 1, 2, 3, 4])
for omega in omega_arr:
    RP_params = set_to_location(loc_params["Taman"]["faceon"], RP_params_1)[0]
    RP_params["theta_tilde"] = 0
    RP_params["omega_tilde"] = omega
    RP_inst = Precessing(RP_params)
    f_arr = np.linspace(20, RP_inst.f_cut(), 100)
    y_data = RP_inst.phase_delta_phi(f_arr)
    plt.plot(f_arr, y_data, label=f"$\~\Omega$ = {omega}")
plt.legend()
plt.grid()
plt.xlabel("f [Hz]")
plt.ylabel("phase_delta_phi")
# Out:
# Text(0, 0.5, 'phase_delta_phi')

# %%
omega_arr = np.array([0, 1, 2, 3, 4])
for omega in omega_arr:
    RP_params = set_to_location(loc_params["Taman"]["faceon"], RP_params_1)[0]
    RP_params["theta_tilde"] = 0
    RP_params["omega_tilde"] = omega
    RP_inst = Precessing(RP_params)
    f_arr = np.linspace(20, RP_inst.f_cut(), 100)
    y_data = RP_inst.LdotN(f_arr)
    plt.plot(f_arr, y_data, label=f"$\~\Omega$ = {omega}")
plt.legend()
plt.grid()
plt.xlabel("f [Hz]")
plt.ylabel("LdotN")
# Out:
# Text(0, 0.5, 'LdotN')

# %%
# Before commenting out the faulty condition `if np.all(np.abs(den_psi) < NEAR_ZERO_THRESHOLD)` or `if den_psi.all() == 0`
omega_arr = np.array([0, 1, 2, 3, 4])
for omega in omega_arr:
    RP_params = set_to_location(loc_params["Taman"]["faceon"], RP_params_1)[0]
    RP_params["theta_tilde"] = 0
    RP_params["omega_tilde"] = omega
    RP_inst = Precessing(RP_params)
    f_arr = np.linspace(20, RP_inst.f_cut(), 100)
    print(RP_inst.polarization_amplitude_and_phase(f_arr))
# Out:
# (0.75, 0, -1)
# (0.75, 0, -1)
# (0.75, 0, -1)
# (0.75, 0, -1)
# (0.75, 0, -1)

# %%
# After
omega_arr = np.array([0, 1, 2, 3, 4])
for omega in omega_arr:
    RP_params = set_to_location(loc_params["Taman"]["faceon"], RP_params_1)[0]
    RP_params["theta_tilde"] = 0
    RP_params["omega_tilde"] = omega
    RP_inst = Precessing(RP_params)
    f_arr = np.linspace(20, RP_inst.f_cut(), 100)
    C, sin2pa, cos2pa = RP_inst.polarization_amplitude_and_phase(f_arr)
    plt.plot(f_arr, y_data, label=f"$\~\Omega$ = {omega}")
plt.legend()
plt.grid()
plt.xlabel("f [Hz]")
plt.ylabel("sin_2pa")
# Out:
# Text(0, 0.5, 'sin_2pa')
