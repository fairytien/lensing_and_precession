# %% [markdown]
# # import modules

# %%
import sys

sys.path.insert(0, "../")

from modules.Classes_ver1 import *
from modules.default_params_ver1 import *
from modules.functions_ver1_draft import *

plt.rcParams["figure.dpi"] = 150

# %% [markdown]
# # assign params

# %%
lens_params, RP_params, NP_params = set_to_params(lens_params_1, RP_params_1, NP_params_1)

# %% [markdown]
# # define functions

# %%
def omit_numerical_errors(arr, n=16, order=1.5) -> np.ndarray:
    """
    Omit numerical errors in an array by replacing values that are greater than a certain order of the median with NaN.

    Parameters:
    - arr (array-like): The input array.
    - n (int): The number of neighbors to consider when calculating the median. Default is 16.
    - order (float): The order of the median used to determine if a value is an error. Default is 1.5.

    Returns:
    - np.ndarray: The modified array with numerical errors omitted.
    """

    assert len(arr) >= n, "Array length must be greater than or equal to n."
    arr_copy = np.array(arr.copy())

    for i in range(len(arr_copy)):
        if i < n // 2:
            neighbors = arr_copy[:n]
        elif i >= len(arr_copy) - n // 2:
            neighbors = arr_copy[-n:]
        else:
            neighbors = arr_copy[i - n // 2 : i + n // 2]

        median = np.nanmedian(neighbors)
        if arr_copy[i] > order * median:
            arr_copy[i] = np.nan

    return arr_copy

# %%
mcz_L_arr = np.linspace(70, 90, 200)

def mismatch_plot_general_zoomed(opt_match=True):
    optimized_mcz_dict = {}
    ep_NP_L_arr = np.zeros(len(mcz_L_arr))
    optimized_ep_NP_L_arr = np.zeros(len(mcz_L_arr))
    optimized_ep_NP_L_mcz = np.zeros(len(mcz_L_arr))

    lens_inst = LensingGeo(lens_params)
    Delta_td = lens_inst.Delta_td()
    I = lens_inst.I()

    for i, mcz_L in enumerate(mcz_L_arr):
        lens_params["mcz"] = RP_params["mcz"] = NP_params["mcz"] = mcz_L * solar_mass

        ep_NP_L = mismatch_general(
            NP_params, lens_params, use_optimized_match=opt_match
        )["mismatch"]
        
        ep_NP_L_arr[i] = ep_NP_L

        optimized_ep_NP_L_dict = optimize_mismatch_mcz_general(
            NP_params, lens_params, use_optimized_match=opt_match
        )
        optimized_ep_NP_L_arr[i] = optimized_ep_NP_L_dict["ep_min"]
        optimized_ep_NP_L_mcz[i] = optimized_ep_NP_L_dict["ep_min_mcz"]

    ep_NP_L_arr = omit_numerical_errors(ep_NP_L_arr)
    optimized_mcz_dict = {
        "mcz_L_arr": mcz_L_arr,
        "ep_NP_L_arr": ep_NP_L_arr,
        "optimized_ep_NP_L_arr": optimized_ep_NP_L_arr,
        "optimized_ep_NP_L_mcz": optimized_ep_NP_L_mcz,
    }

    # plot mismatch vs mcz
    plt.plot(mcz_L_arr, optimized_mcz_dict["ep_NP_L_arr"], label=r"$\epsilon$", ls="-")

    plt.xlabel(r"$\mathcal{M}_{\text{s}}$ $[M_{\odot}]$")
    plt.ylabel(r"$\epsilon(\~h_{\rm NP}, \~h_{\rm L})$")
    plt.legend()
    plt.title(
        r"$\theta_S$ = {:.3g}, $\phi_S$ = {:.3g}, $\theta_J$ = {:.3g}, $\phi_J$ = {:.3g}, $\Delta t_d$ = {:.3g} s, $I$ = {:.3g}".format(
            lens_params["theta_S"],
            lens_params["phi_S"],
            lens_params["theta_J"],
            lens_params["phi_J"],
            Delta_td,
            I,
        )
    )

    plt.suptitle(r"Actual Mismatch Between NP Templates & a Lensed Source")

    return optimized_mcz_dict

# %% [markdown]
# # mismatch optimized over $\tilde{\theta}$, $\tilde{\Omega}$, and $\gamma_P$

# %%
from multiprocessing import Pool

def compute_mismatch(r, c, t_params, s_params, lens_Class, prec_Class, opt_match):
    n_pts = 20
    omega_tilde_arr = np.linspace(0, 3, n_pts)
    theta_tilde_arr = np.linspace(0, 8, n_pts)
    X, Y = np.meshgrid(omega_tilde_arr, theta_tilde_arr)
    t_params["omega_tilde"] = X[r, c]
    t_params["theta_tilde"] = Y[r, c]

    optimized_mismatch_results_dict = optimize_mismatch_gammaP_general(t_params, s_params, lens_Class, prec_Class, opt_match)

    return optimized_mismatch_results_dict["ep_min"], optimized_mismatch_results_dict["ep_min_gamma"]

def mismatch_contour_parallel(t_params, s_params, lens_Class=LensingGeo, prec_Class=Precessing, opt_match=True):
    n_pts = 20
    omega_tilde_arr = np.linspace(0, 3, n_pts)
    theta_tilde_arr = np.linspace(0, 8, n_pts)
    X, Y = np.meshgrid(omega_tilde_arr, theta_tilde_arr)
    Z = np.zeros_like(X)
    g_min_matrix = np.zeros_like(X)

    # Create a pool of worker processes
    with Pool() as pool:
        results = []
        for r in range(n_pts):
            for c in range(n_pts):
                results.append(pool.apply_async(compute_mismatch, args=(r, c, t_params, s_params, lens_Class, prec_Class, opt_match)))

        for r in range(n_pts):
            for c in range(n_pts):
                idx = r * n_pts + c
                Z[r, c], g_min_matrix[r, c] = results[idx].get()

    min_idx = np.unravel_index(np.argmin(Z, axis=None), Z.shape)
    max_idx = np.unravel_index(np.argmax(Z, axis=None), Z.shape)
    results_dict = {
        "ep_0_0": Z[0, 0],
        "ep_min": Z[min_idx],
        "ep_min_omega_tilde": X[min_idx],
        "ep_min_theta_tilde": Y[min_idx],
        "ep_min_gamma_P": g_min_matrix[min_idx],
        "ep_max": Z[max_idx],
        "ep_max_omega_tilde": X[max_idx],
        "ep_max_theta_tilde": Y[max_idx],
        "ep_max_gamma_P": g_min_matrix[max_idx],
        "ep_max_min_ratio": Z[max_idx] / Z[min_idx],
        }
    return results_dict

# %% [markdown]
# ## as a function of $\mathcal{M}_{\text{s}}$

# %%
lens_params, RP_params, NP_params = set_to_params(lens_params_1, RP_params_1, NP_params_1)

mcz_L_arr = np.linspace(50, 90, 100)
lens_params["MLz"] = 3e3 * solar_mass
mismatch_mcz_dict = {}

for mcz in mcz_L_arr:
    lens_params["mcz"] = RP_params["mcz"] = mcz * solar_mass
    mismatch_mcz_dict[mcz] = mismatch_contour_parallel(RP_params, lens_params)

# %%
mismatch_mcz_dict
# Out:
# {50.0: {'ep_0_0': 0.16310220281208276,
#   'ep_min': 0.0012669978230447354,
#   'ep_min_omega_tilde': 0.7894736842105263,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.013854942092801,
#   'ep_max': 0.16310220281208276,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 128.73124155819795},
#  50.4040404040404: {'ep_0_0': 0.16358118409633626,
#   'ep_min': 0.001493183360424366,
#   'ep_min_omega_tilde': 0.7894736842105263,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.013854942092801,
#   'ep_max': 0.16358118409633626,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 109.55197361015738},
#  50.80808080808081: {'ep_0_0': 0.16360645665263396,
#   'ep_min': 0.0017262868029885858,
#   'ep_min_omega_tilde': 0.7894736842105263,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.013854942092801,
#   'ep_max': 0.16360645665263396,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 94.7736241564234},
#  51.21212121212121: {'ep_0_0': 0.16347883431913135,
#   'ep_min': 0.0020424094084340316,
#   'ep_min_omega_tilde': 0.7894736842105263,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.013854942092801,
#   'ep_max': 0.16347883431913135,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 80.04214710530286},
#  51.61616161616162: {'ep_0_0': 0.16319066061794063,
#   'ep_min': 0.0022635283069568635,
#   'ep_min_omega_tilde': 1.5789473684210527,
#   'ep_min_theta_tilde': 6.315789473684211,
#   'ep_min_gamma_P': 4.6330558325667655,
#   'ep_max': 0.16319066061794063,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 72.09570126266178},
#  52.02020202020202: {'ep_0_0': 0.16273424279268445,
#   'ep_min': 0.0022000045650439892,
#   'ep_min_omega_tilde': 0.47368421052631576,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.204254496855819,
#   'ep_max': 0.16273424279268445,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 73.96995687117156},
#  52.42424242424242: {'ep_0_0': 0.16210189641459205,
#   'ep_min': 0.0020195415903236924,
#   'ep_min_omega_tilde': 0.47368421052631576,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.204254496855819,
#   'ep_max': 0.16210189641459205,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 80.26667892915755},
#  52.82828282828283: {'ep_0_0': 0.16027908531083612,
#   'ep_min': 0.001985231885896055,
#   'ep_min_omega_tilde': 0.47368421052631576,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.204254496855819,
#   'ep_max': 0.16027908531083612,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 80.73569966789672},
#  53.23232323232323: {'ep_0_0': 0.15907389980416065,
#   'ep_min': 0.0019345364056920777,
#   'ep_min_omega_tilde': 0.47368421052631576,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.204254496855819,
#   'ep_max': 0.15907389980416065,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 1.5231964381041423,
#   'ep_max_min_ratio': 82.22843433502207},
#  53.63636363636363: {'ep_0_0': 0.1576635581163197,
#   'ep_min': 0.0019696399548687626,
#   'ep_min_omega_tilde': 0.47368421052631576,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.204254496855819,
#   'ep_max': 0.1576635581163197,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 80.04689269558652},
#  54.04040404040404: {'ep_0_0': 0.15604167572001182,
#   'ep_min': 0.0021055888227253794,
#   'ep_min_omega_tilde': 0.47368421052631576,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.204254496855819,
#   'ep_max': 0.15604167572001182,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.06346651825433926,
#   'ep_max_min_ratio': 74.10833209023141},
#  54.44444444444444: {'ep_0_0': 0.1542025585375364,
#   'ep_min': 0.0021930064351581846,
#   'ep_min_omega_tilde': 0.3157894736842105,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.267721015110158,
#   'ep_max': 0.1542025585375364,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 70.31559783198426},
#  54.84848484848485: {'ep_0_0': 0.15214143352111842,
#   'ep_min': 0.002168810573921043,
#   'ep_min_omega_tilde': 0.3157894736842105,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.267721015110158,
#   'ep_max': 0.15214143352111864,
#   'ep_max_omega_tilde': 0.15789473684210525,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 70.14971032996147},
#  55.25252525252525: {'ep_0_0': 0.14985473201973853,
#   'ep_min': 0.0023409260311206825,
#   'ep_min_omega_tilde': 0.3157894736842105,
#   'ep_min_theta_tilde': 6.7368421052631575,
#   'ep_min_gamma_P': 5.267721015110158,
#   'ep_max': 0.14985473201973865,
#   'ep_max_omega_tilde': 0.47368421052631576,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 64.01515042660189},
#  55.656565656565654: {'ep_0_0': 0.1473404356969088,
#   'ep_min': 0.0027143271689428206,
#   'ep_min_omega_tilde': 2.3684210526315788,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gamma_P': 4.3157232412950695,
#   'ep_max': 0.1473404356969088,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.06346651825433926,
#   'ep_max_min_ratio': 54.282489370761866},
#  56.06060606060606: {'ep_0_0': 0.14459849582696116,
#   'ep_min': 0.002776251018497433,
#   'ep_min_omega_tilde': 2.3684210526315788,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gamma_P': 4.3157232412950695,
#   'ep_max': 0.14459849582696138,
#   'ep_max_omega_tilde': 0.47368421052631576,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 52.08408564770962},
#  56.464646464646464: {'ep_0_0': 0.14163133759941582,
#   'ep_min': 0.002664197913849975,
#   'ep_min_omega_tilde': 1.894736842105263,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gamma_P': 4.569589314312426,
#   'ep_max': 0.14163133759941582,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 53.16096708248954},
#  56.868686868686865: {'ep_0_0': 0.13844446133496768,
#   'ep_min': 0.002562768418262973,
#   'ep_min_omega_tilde': 1.894736842105263,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gamma_P': 4.569589314312426,
#   'ep_max': 0.1384444613349678,
#   'ep_max_omega_tilde': 0.9473684210526315,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 54.02144819187546},
#  57.27272727272727: {'ep_0_0': 0.1350471518601526,
#   'ep_min': 0.0024808788262646875,
#   'ep_min_omega_tilde': 2.052631578947368,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gamma_P': 4.506122796058087,
#   'ep_max': 0.1350471518601526,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 54.43520676238956},
#  57.676767676767675: {'ep_0_0': 0.13145330511425335,
#   'ep_min': 0.0023950938601889904,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.0618571682777125,
#   'ep_max': 0.13145330511425335,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.06346651825433926,
#   'ep_max_min_ratio': 54.88440653590116},
#  58.08080808080808: {'ep_0_0': 0.12768237654263193,
#   'ep_min': 0.002341034784741014,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.0618571682777125,
#   'ep_max': 0.12768237654263193,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 54.54099929436003},
#  58.484848484848484: {'ep_0_0': 0.12376044783453033,
#   'ep_min': 0.00239209456678402,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.0618571682777125,
#   'ep_max': 0.12376044783453044,
#   'ep_max_omega_tilde': 0.15789473684210525,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 51.7372722437627},
#  58.888888888888886: {'ep_0_0': 0.11972139560849149,
#   'ep_min': 0.0021554759394317724,
#   'ep_min_omega_tilde': 2.8421052631578947,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.188790204786391,
#   'ep_max': 0.11972139560849149,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 55.542905127510956},
#  59.292929292929294: {'ep_0_0': 0.11972139560849138,
#   'ep_min': 0.002023643317327184,
#   'ep_min_omega_tilde': 2.8421052631578947,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.188790204786391,
#   'ep_max': 0.11972139560849138,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 59.16131295638536},
#  59.696969696969695: {'ep_0_0': 0.11560812589186531,
#   'ep_min': 0.0018319542042846138,
#   'ep_min_omega_tilde': 2.8421052631578947,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.188790204786391,
#   'ep_max': 0.11560812589186531,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 63.10644972536898},
#  60.101010101010104: {'ep_0_0': 0.11147380955496689,
#   'ep_min': 0.0016974501779456475,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.1253236865320515,
#   'ep_max': 0.111473809554967,
#   'ep_max_omega_tilde': 0.3157894736842105,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 65.67132926981047},
#  60.505050505050505: {'ep_0_0': 0.10738301407181039,
#   'ep_min': 0.0016239468614848152,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.1253236865320515,
#   'ep_max': 0.10738301407181061,
#   'ep_max_omega_tilde': 0.15789473684210525,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 66.12470926150111},
#  60.90909090909091: {'ep_0_0': 0.1034125743757276,
#   'ep_min': 0.001661005169894647,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.1253236865320515,
#   'ep_max': 0.1034125743757276,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 62.259032211372805},
#  61.313131313131315: {'ep_0_0': 0.099651979814395,
#   'ep_min': 0.0018305322954734748,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.1253236865320515,
#   'ep_max': 0.09965197981439522,
#   'ep_max_omega_tilde': 0.15789473684210525,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 54.43879906452009},
#  61.717171717171716: {'ep_0_0': 0.09965197981439522,
#   'ep_min': 0.0017611604606023734,
#   'ep_min_omega_tilde': 2.526315789473684,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.3791897595494085,
#   'ep_max': 0.09965197981439533,
#   'ep_max_omega_tilde': 0.15789473684210525,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.06346651825433926,
#   'ep_max_min_ratio': 56.58313483844121},
#  62.121212121212125: {'ep_0_0': 0.09620297773223507,
#   'ep_min': 0.001473910461114003,
#   'ep_min_omega_tilde': 2.526315789473684,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.3791897595494085,
#   'ep_max': 0.09620297773223507,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 65.27057122555698},
#  62.525252525252526: {'ep_0_0': 0.09317801423507666,
#   'ep_min': 0.0012514357157026312,
#   'ep_min_omega_tilde': 2.526315789473684,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4.3791897595494085,
#   'ep_max': 0.09317801423507666,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.12693303650867852,
#   'ep_max_min_ratio': 74.4568922445696},
#  62.92929292929293: {'ep_0_0': 0.09069706354184137,
#   'ep_min': 0.0011086507536482992,
#   'ep_min_omega_tilde': 2.526315789473684,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gamma_P': 4

#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 10089.788590968697},
#  89.5959595959596: {'ep_0_0': 0.00131830049300663,
#   'ep_min': 1.1629781315747323e-07,
#   'ep_min_omega_tilde': 2.8421052631578947,
#   'ep_min_theta_tilde': 5.052631578947368,
#   'ep_min_gamma_P': 4.569589314312426,
#   'ep_max': 0.00131830049300663,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.06346651825433926,
#   'ep_max_min_ratio': 11335.557025664646},
#  90.0: {'ep_0_0': 0.00131830049300663,
#   'ep_min': 1.4589387176133783e-07,
#   'ep_min_omega_tilde': 2.8421052631578947,
#   'ep_min_theta_tilde': 5.052631578947368,
#   'ep_min_gamma_P': 4.569589314312426,
#   'ep_max': 0.001318300493006741,
#   'ep_max_omega_tilde': 0.15789473684210525,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gamma_P': 0.0,
#   'ep_max_min_ratio': 9036.023769136089}}

# %%
ep_min_arr = np.array([mismatch_mcz_dict[mcz]["ep_min"] for mcz in mcz_L_arr])
plt.plot(mcz_L_arr, ep_min_arr, label=r"$\epsilon(\~h_{\rm RP}, \~h_{\rm L})$")
plt.legend()
plt.xlabel(r"$\mathcal{M}_{\text{s}}$ $[M_{\odot}]$")
plt.ylabel(r"$\epsilon(\~h_{\rm RP}, \~h_{\rm L})$")

# get lensing parameters
lens_inst = LensingGeo(lens_params)
Delta_td = lens_inst.Delta_td()
I = lens_inst.I()

plt.title(
    r"$\theta_S$ = {:.3g}, $\phi_S$ = {:.3g}, $\theta_J$ = {:.3g}, $\phi_J$ = {:.3g}, $\Delta t_d$ = {:.3g} s, $I$ = {:.3g}".format(
        lens_params["theta_S"],
        lens_params["phi_S"],
        lens_params["theta_J"],
        lens_params["phi_J"],
        Delta_td,
        I,
    )
)

plt.suptitle(
    r"Mismatch Between RP Templates & a Lensed Source"
)

plt.show()

# %%
mcz_L_arr = np.linspace(50, 90, 100)

ep_min_arr = np.array([mismatch_mcz_dict[mcz]["ep_min"] for mcz in mcz_L_arr])
plt.plot(mcz_L_arr, ep_min_arr, label=r"$\epsilon(\~h_{\rm RP}, \~h_{\rm L})$")
plt.legend()
plt.xlabel(r"$\mathcal{M}_{\text{s}}$ $[M_{\odot}]$")
plt.ylabel(r"$\epsilon(\~h_{\rm RP}, \~h_{\rm L})$")

# get lensing parameters
lens_inst = LensingGeo(lens_params)
Delta_td = lens_inst.Delta_td()
I = lens_inst.I()

plt.title(
    r"$\theta_S$ = {:.3g}, $\phi_S$ = {:.3g}, $\theta_J$ = {:.3g}, $\phi_J$ = {:.3g}, $\Delta t_d$ = {:.3g} s, $I$ = {:.3g}".format(
        lens_params["theta_S"],
        lens_params["phi_S"],
        lens_params["theta_J"],
        lens_params["phi_J"],
        Delta_td,
        I,
    )
)

plt.suptitle(
    r"Mismatch Between RP Templates & a Lensed Source"
)

################################################################################

lens_params, RP_params, NP_params = set_to_params(lens_params_1, RP_params_1, NP_params_1)

MLz_range = np.array([3e3])
mismatch_plots_dict = {}

for MLz in MLz_range:
    lens_params["MLz"] = MLz * solar_mass
    mismatch_plots_dict[MLz] = mismatch_plot_general_zoomed(opt_match=True)
    plt.show()
