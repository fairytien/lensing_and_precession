# %% [markdown]
# # import modules

# %%
import sys

sys.path.insert(0, "../")

from modules.Classes_v2 import *
from modules.default_params_v1 import *
from modules.functions_v2 import *
from multiprocessing import Pool, cpu_count

print("Number of cores: ", cpu_count())
# Out:
# Number of cores:  8

# %% [markdown]
# # assign params

# %%
lens_params, RP_params, NP_params = set_to_params(
    lens_params_1, RP_params_1, NP_params_1
)

# %% [markdown]
# # mismatch optimized over $\tilde{\theta}$, $\tilde{\Omega}$, and $\gamma_P$

# %%
from multiprocessing import Pool


def compute_mismatch(r, c, tpl_params, src_params, opt_match):
    n_pts = 20
    omega_tilde_arr = np.linspace(0, 3, n_pts)
    theta_tilde_arr = np.linspace(0, 8, n_pts)
    X, Y = np.meshgrid(omega_tilde_arr, theta_tilde_arr)
    tpl_params["omega_tilde"] = X[r, c]
    tpl_params["theta_tilde"] = Y[r, c]

    optimized_mismatch_results_dict = optimize_mismatch_gammaP(
        tpl_params, src_params, use_opt_match=opt_match
    )

    return (
        optimized_mismatch_results_dict["ep_min"],
        optimized_mismatch_results_dict["ep_min_gammaP"],
    )


def mismatch_contour_parallel(tpl_params, src_params, opt_match=True):
    n_pts = 20
    omega_tilde_arr = np.linspace(0, 3, n_pts)
    theta_tilde_arr = np.linspace(0, 8, n_pts)
    X, Y = np.meshgrid(omega_tilde_arr, theta_tilde_arr)
    Z = np.zeros_like(X)
    g_min_matrix = np.zeros_like(X)

    # Create a pool of worker processes
    with Pool(cpu_count()) as pool:  # Use maximum number of cores
        results = []
        for r in range(n_pts):
            for c in range(n_pts):
                results.append(
                    pool.apply_async(
                        compute_mismatch, args=(r, c, tpl_params, src_params, opt_match)
                    )
                )

        for r in range(n_pts):
            for c in range(n_pts):
                idx = r * n_pts + c
                Z[r, c], g_min_matrix[r, c] = results[idx].get()

    min_idx = np.unravel_index(np.argmin(Z, axis=None), Z.shape)
    max_idx = np.unravel_index(np.argmax(Z, axis=None), Z.shape)

    results_dict = {
        "ep_0_0": Z[0, 0],
        "ep_min": Z[min_idx],
        "ep_min_omega_tilde": X[min_idx],
        "ep_min_theta_tilde": Y[min_idx],
        "ep_min_gammaP": g_min_matrix[min_idx],
        "ep_max": Z[max_idx],
        "ep_max_omega_tilde": X[max_idx],
        "ep_max_theta_tilde": Y[max_idx],
        "ep_max_gammaP": g_min_matrix[max_idx],
        "ep_max_min_ratio": Z[max_idx] / Z[min_idx],
    }

    return results_dict

# %% [markdown]
# # as a function of $\Delta t_d$ while fixing $I$

# %%
lens_params, RP_params, NP_params = set_to_params(
    lens_params_1, RP_params_1, NP_params_1
)

I = LensingGeo(lens_params).I()
MLz_arr = np.linspace(400, 4600, 30)
Delta_td_arr = np.zeros_like(MLz_arr)

mismatch_Deltatd_dict = {}

for i, MLz in enumerate(MLz_arr):
    lens_params["MLz"] = MLz * solar_mass
    Delta_td = LensingGeo(lens_params).td()
    Delta_td_arr[i] = Delta_td
    # mismatch_Deltatd_dict[Delta_td] = mismatch_contour_parallel(RP_params, lens_params)

# %%
# now = datetime.now()
# filename = "mismatch_Deltatd_dict_" + now.strftime("%Y-%m-%d_%H-%M-%S") + ".pkl"
# filepath = os.path.join("data", filename)
# with open(filepath, "wb") as f:
#     pickle.dump(mismatch_Deltatd_dict, f)
#     print("Results saved as", filepath)
# Out:
# Results saved as data/mismatch_Deltatd_dict_2024-04-16_17-48-12.pkl

# %%
filepath = "../data/mismatch_Deltatd_dict_2024-04-16_17-48-12.pkl"
with open(filepath, "rb") as f:
    mismatch_Deltatd_dict = pickle.load(f)

mismatch_Deltatd_dict
# Out:
# {0.003951231688892276: {'ep_0_0': 0.0004046274597211408,
#   'ep_min': 0.00014795117200416819,
#   'ep_min_omega_tilde': 0.3157894736842105,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gammaP': 0.6346651825433925,
#   'ep_max': 0.16618348223586987,
#   'ep_max_omega_tilde': 3.0,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 2.221328138901874,
#   'ep_max_min_ratio': 1123.2319418949114},
#  0.0053818500590084445: {'ep_0_0': 0.005022767198758826,
#   'ep_min': 0.0012585973738398204,
#   'ep_min_omega_tilde': 0.47368421052631576,
#   'ep_min_theta_tilde': 7.578947368421052,
#   'ep_min_gammaP': 0.25386607301735703,
#   'ep_max': 0.17127336300763119,
#   'ep_max_omega_tilde': 3.0,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 2.3482611754105527,
#   'ep_max_min_ratio': 136.08272714338975},
#  0.006812468429124613: {'ep_0_0': 0.03313238816761299,
#   'ep_min': 0.006618025041765452,
#   'ep_min_omega_tilde': 0.0,
#   'ep_min_theta_tilde': 5.052631578947368,
#   'ep_min_gammaP': 5.458120569873176,
#   'ep_max': 0.19248034884972176,
#   'ep_max_omega_tilde': 3.0,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 2.6655937666822487,
#   'ep_max_min_ratio': 29.08425816387889},
#  0.008243086799240781: {'ep_0_0': 0.12892245631481292,
#   'ep_min': 0.009821357647426754,
#   'ep_min_omega_tilde': 1.1052631578947367,
#   'ep_min_theta_tilde': 5.473684210526315,
#   'ep_min_gammaP': 6.156252270670908,
#   'ep_max': 0.2188663569635353,
#   'ep_max_omega_tilde': 3.0,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 3.3002589492256416,
#   'ep_max_min_ratio': 22.284735453135585},
#  0.009673705169356952: {'ep_0_0': 0.24110830113012738,
#   'ep_min': 0.011366500636656673,
#   'ep_min_omega_tilde': 1.263157894736842,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gammaP': 5.775453161144872,
#   'ep_max': 0.24110830113012738,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 21.212183840694056},
#  0.011104323539473122: {'ep_0_0': 0.19740046493876184,
#   'ep_min': 0.012270545681364542,
#   'ep_min_omega_tilde': 1.263157894736842,
#   'ep_min_theta_tilde': 6.315789473684211,
#   'ep_min_gammaP': 6.156252270670908,
#   'ep_max': 0.19740046493876184,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 16.08734200293609},
#  0.012534941909589288: {'ep_0_0': 0.1814604653774976,
#   'ep_min': 0.00875164390824168,
#   'ep_min_omega_tilde': 1.4210526315789473,
#   'ep_min_theta_tilde': 6.315789473684211,
#   'ep_min_gammaP': 5.775453161144872,
#   'ep_max': 0.1814604653774976,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 20.734443412009824},
#  0.013965560279705457: {'ep_0_0': 0.18615036845327626,
#   'ep_min': 0.0065229157265608295,
#   'ep_min_omega_tilde': 1.263157894736842,
#   'ep_min_theta_tilde': 7.157894736842104,
#   'ep_min_gammaP': 0.4442656277803748,
#   'ep_max': 0.18615036845327626,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 28.537907932074877},
#  0.015396178649821627: {'ep_0_0': 0.3327309105593269,
#   'ep_min': 0.01022840544398862,
#   'ep_min_omega_tilde': 0.9473684210526315,
#   'ep_min_theta_tilde': 7.578947368421052,
#   'ep_min_gammaP': 1.967462065884517,
#   'ep_max': 0.3327309105593269,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 32.53008617827891},
#  0.016826797019937795: {'ep_0_0': 0.17996230397033153,
#   'ep_min': 0.013494451597402368,
#   'ep_min_omega_tilde': 2.052631578947368,
#   'ep_min_theta_tilde': 7.157894736842104,
#   'ep_min_gammaP': 4.696522350821105,
#   'ep_max': 0.17996230397033153,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 13.336022043680057},
#  0.018257415390053964: {'ep_0_0': 0.18580025863599203,
#   'ep_min': 0.020701446707177995,
#   'ep_min_omega_tilde': 2.2105263157894735,
#   'ep_min_theta_tilde': 8.0,
#   'ep_min_gammaP': 4.506122796058087,
#   'ep_max': 0.18580025863599203,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 8.97523063311164},
#  0.019688033760170132: {'ep_0_0': 0.21989492114004783,
#   'ep_min': 0.04373502708520438,
#   'ep_min_omega_tilde': 2.2105263157894735,
#   'ep_min_theta_tilde': 8.0,
#   'ep_min_gammaP': 4.950388423838462,
#   'ep_max': 0.21989492114004783,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 5.027890361463583},
#  0.021118652130286304: {'ep_0_0': 0.24108577414913934,
#   'ep_min': 0.07774984218784609,
#   'ep_min_omega_tilde': 2.2105263157894735,
#   'ep_min_theta_tilde': 8.0,
#   'ep_min_gammaP': 5.267721015110158,
#   'ep_max': 0.24108577414913934,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 3.1007879548702935},
#  0.022549270500402466: {'ep_0_0': 0.22275549668289674,
#   'ep_min': 0.09255646024360209,
#   'ep_min_omega_tilde': 2.052631578947368,
#   'ep_min_theta_tilde': 8.0,
#   'ep_min_gammaP': 0.0,
#   'ep_max': 0.22275549668289674,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 2.4066985286237172},
#  0.023979888870518638: {'ep_0_0': 0.20423540408926788,
#   'ep_min': 0.07192538446979213,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gammaP': 4.188790204786391,
#   'ep_max': 0.20423540408926788,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 2.839545531731492},
#  0.025410507240634806: {'ep_0_0': 0.1947340223600923,
#   'ep_min': 0.053532619013849536,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 6.315789473684211,
#   'ep_min_gammaP': 4.506122796058087,
#   'ep_max': 0.1947340223600923,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 3.637670376443048},
#  0.026841125610750975: {'ep_0_0': 0.34575415173716684,
#   'ep_min': 0.05322224437696088,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 6.315789473684211,
#   'ep_min_gammaP': 4.823455387329783,
#   'ep_max': 0.34575415173716684,
#   'ep_max_omega_tilde': 0.0,
#   'ep_max_theta_tilde': 0.0,
#   'ep_max_gammaP': 0.0,
#   'ep_max_min_ratio': 6.496421858655},
#  0.028271743980867146: {'ep_0_0': 0.1979555047278232,
#   'ep_min': 0.08209612167035896,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gammaP': 5.14078797860148,
#   'ep_max': 0.20043228578011707,
#   'ep_max_omega_tilde': 0.9473684210526315,
#   'ep_max_theta_tilde': 2.1052631578947367,
#   'ep_max_gammaP': 1.6501294746128208,
#   'ep_max_min_ratio': 2.4414342809629184},
#  0.02970236235098331: {'ep_0_0': 0.21440927462633141,
#   'ep_min': 0.1256291494462144,
#   'ep_min_omega_tilde': 1.7368421052631577,
#   'ep_min_theta_tilde': 8.0,
#   'ep_min_gammaP': 2.475194211919231,
#   'ep_max': 0.21452726176846748,
#   'ep_max_omega_tilde': 0.15789473684210525,
#   'ep_max_theta_tilde': 3.3684210526315788,
#   'ep_max_gammaP': 1.6501294746128208,
#   'ep_max_min_ratio': 1.7076232921589032},
#  0.031132980721099483: {'ep_0_0': 0.2293589305178425,
#   'ep_min': 0.1553619193764414,
#   'ep_min_omega_tilde': 1.7368421052631577,
#   'ep_min_theta_tilde': 8.0,
#   'ep_min_gammaP': 2.6655937666822487,
#   'ep_max': 0.2680351359856046,
#   'ep_max_omega_tilde': 2.6842105263157894,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 1.6501294746128208,
#   'ep_max_min_ratio': 1.725230591005743},
#  0.03256359909121565: {'ep_0_0': 0.224228990320139,
#   'ep_min': 0.19077897412908162,
#   'ep_min_omega_tilde': 1.4210526315789473,
#   'ep_min_theta_tilde': 7.578947368421052,
#   'ep_min_gammaP': 3.998390650023373,
#   'ep_max': 0.33335996026105086,
#   'ep_max_omega_tilde': 2.526315789473684,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 5.458120569873176,
#   'ep_max_min_ratio': 1.7473621597079063},
#  0.03399421746133181: {'ep_0_0': 0.20938629619095261,
#   'ep_min': 0.19653175822493496,
#   'ep_min_omega_tilde': 1.1052631578947367,
#   'ep_min_theta_tilde': 7.578947368421052,
#   'ep_min_gammaP': 5.204254496855819,
#   'ep_max': 0.33808032116832987,
#   'ep_max_omega_tilde': 2.3684210526315788,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 1.1423973285781066,
#   'ep_max_min_ratio': 1.7202325172371857},
#  0.03542483583144798: {'ep_0_0': 0.19861906721405997,
#   'ep_min': 0.18715766971956882,
#   'ep_min_omega_tilde': 1.7368421052631577,
#   'ep_min_theta_tilde': 1.6842105263157894,
#   'ep_min_gammaP': 4.442656277803748,
#   'ep_max': 0.3352421844302398,
#   'ep_max_omega_tilde': 2.052631578947368,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 1.2058638468324459,
#   'ep_max_min_ratio': 1.791228673302869},
#  0.03685545420156416: {'ep_0_0': 0.19450976111044815,
#   'ep_min': 0.1808523330873013,
#   'ep_min_omega_tilde': 1.7368421052631577,
#   'ep_min_theta_tilde': 2.1052631578947367,
#   'ep_min_gammaP': 4.696522350821105,
#   'ep_max': 0.3126019457954031,
#   'ep_max_omega_tilde': 2.052631578947368,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 4.0618571682777125,
#   'ep_max_min_ratio': 1.7284927457612804},
#  0.038286072571680325: {'ep_0_0': 0.1975194744241192,
#   'ep_min': 0.1798713082976514,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 4.2105263157894735,
#   'ep_min_gammaP': 1.7770625111214993,
#   'ep_max': 0.30091466764174235,
#   'ep_max_omega_tilde': 2.052631578947368,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 4.25225672304073,
#   'ep_max_min_ratio': 1.6729442315713194},
#  0.039716690941796494: {'ep_0_0': 0.2080593590976818,
#   'ep_min': 0.17861424171093954,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.894736842105263,
#   'ep_min_gammaP': 2.1578616206475347,
#   'ep_max': 0.30441298188691424,
#   'ep_max_omega_tilde': 1.894736842105263,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 5.14078797860148,
#   'ep_max_min_ratio': 1.7043040855586487},
#  0.04114730931191266: {'ep_0_0': 0.22021356172639672,
#   'ep_min': 0.18403886675760495,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 5.052631578947368,
#   'ep_min_gammaP': 2.4117276936648917,
#   'ep_max': 0.3154989017134622,
#   'ep_max_omega_tilde': 1.7368421052631577,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 2.729060284936588,
#   'ep_max_min_ratio': 1.7143058271979115},
#  0.04257792768202883: {'ep_0_0': 0.22127703127079745,
#   'ep_min': 0.1906877173163073,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 3.789473684210526,
#   'ep_min_gammaP': 2.6021272484279097,
#   'ep_max': 0.30880472222248534,
#   'ep_max_omega_tilde': 1.7368421052631577,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 1.5231964381041423,
#   'ep_max_min_ratio': 1.6194263928926735},
#  0.044008546052145: {'ep_0_0': 0.21144511182512038,
#   'ep_min': 0.1933988528959386,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 2.526315789473684,
#   'ep_min_gammaP': 2.8559933214452666,
#   'ep_max': 0.29285676145724504,
#   'ep_max_omega_tilde': 1.7368421052631577,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 1.6501294746128208,
#   'ep_max_min_ratio': 1.5142631772217459},
#  0.045439164422261175: {'ep_0_0': 0.2017272398183002,
#   'ep_min': 0.19221594723018842,
#   'ep_min_omega_tilde': 3.0,
#   'ep_min_theta_tilde': 1.6842105263157894,
#   'ep_min_gammaP': 3.42719198573432,
#   'ep_max': 0.321660797663467,
#   'ep_max_omega_tilde': 3.0,
#   'ep_max_theta_tilde': 8.0,
#   'ep_max_gammaP': 2.6655937666822487,
#   'ep_max_min_ratio': 1.673434500615403}}

# %%
Deltatd_ep_min_arr = np.array(
    [mismatch_Deltatd_dict[Delta_td]["ep_min"] for Delta_td in Delta_td_arr]
)

plt.plot(
    Delta_td_arr, Deltatd_ep_min_arr, label=r"$\epsilon(\~h_{\rm RP}, \~h_{\rm L})$"
)
plt.xlabel(r"$\Delta t_d$ [s]")
plt.ylabel(r"$\epsilon(\~h_{\rm RP}, \~h_{\rm L})$")

plt.title(
    r"$\theta_S$ = {:.3g}, $\phi_S$ = {:.3g}, $\theta_J$ = {:.3g}, $\phi_J$ = {:.3g}, {} = {:.3g} {}, $I$ = {:.3g}".format(
        lens_params["theta_S"],
        lens_params["phi_S"],
        lens_params["theta_J"],
        lens_params["phi_J"],
        r"$\mathcal{M}_{\text{s}}$",
        lens_params["mcz"] / solar_mass,
        r"$M_{\odot}$",
        I,
    )
)

plt.suptitle(
    r"Mismatch Between RP Templates & a Lensed Source as a Function of $\Delta t_d$"
)

plt.show()

# %%
Deltatd_ep_min_omega_tilde_arr = np.array(
    [mismatch_Deltatd_dict[Delta_td]["ep_min_omega_tilde"] for Delta_td in Delta_td_arr]
)

plt.plot(Delta_td_arr, Deltatd_ep_min_omega_tilde_arr, label=r"$\~{\Omega}_{\rm best}$")
plt.xlabel(r"$\Delta t_d$ [s]")
plt.ylabel(r"$\~{\Omega}_{\rm best}$")

plt.title(
    r"$\theta_S$ = {:.3g}, $\phi_S$ = {:.3g}, $\theta_J$ = {:.3g}, $\phi_J$ = {:.3g}, {} = {:.3g} {}, $I$ = {:.3g}".format(
        lens_params["theta_S"],
        lens_params["phi_S"],
        lens_params["theta_J"],
        lens_params["phi_J"],
        r"$\mathcal{M}_{\text{s}}$",
        lens_params["mcz"] / solar_mass,
        r"$M_{\odot}$",
        I,
    )
)

plt.suptitle(
    r"Mismatch Between RP Templates & a Lensed Source as a Function of $\Delta t_d$"
)

plt.show()

# %% [markdown]
# # as a function of $I$ while fixing $\Delta t_d$

# %%
lens_params, RP_params, NP_params = set_to_params(
    lens_params_1, RP_params_1, NP_params_1
)

# create y_range and MLz_range based on the same time delay
y_arr = np.linspace(0.5, 3, 50)[::-1]
time_delay = 0.1
MLz_arr = get_MLz_from_td(time_delay, y_arr)
I_arr = np.zeros_like(MLz_arr)

mismatch_I_dict = {}

for i, y, MLz in zip(range(len(y_arr)), y_arr, MLz_arr):
    lens_params["y"] = y
    lens_params["MLz"] = MLz * solar_mass
    I = LensingGeo(lens_params).I()
    I_arr[i] = I
    mismatch_I_dict[I] = mismatch_contour_parallel(RP_params, lens_params)

now = datetime.now()
filename = "mismatch_I_dict_" + now.strftime("%Y-%m-%d_%H-%M-%S") + ".pkl"
filepath = os.path.join("data", filename)
with open(filepath, "wb") as f:
    pickle.dump(mismatch_I_dict, f)
    print("Results saved as", filepath)
# Out:
# Results saved as data/mismatch_I_dict_2024-03-18_16-03-10.pkl

# %%
I_ep_min_arr = np.array([mismatch_I_dict[I]["ep_min"] for I in I_arr])

plt.plot(I_arr, I_ep_min_arr, label=r"$\epsilon(\~h_{\rm RP}, \~h_{\rm L})$")
plt.xlabel(r"$I$")
plt.ylabel(r"$\epsilon(\~h_{\rm RP}, \~h_{\rm L})$")

plt.title(
    r"$\theta_S$ = {:.3g}, $\phi_S$ = {:.3g}, $\theta_J$ = {:.3g}, $\phi_J$ = {:.3g}, {} = {:.3g} {}, $\Delta t_d$ = {:.3g} s".format(
        lens_params["theta_S"],
        lens_params["phi_S"],
        lens_params["theta_J"],
        lens_params["phi_J"],
        r"$\mathcal{M}_{\text{s}}$",
        lens_params["mcz"] / solar_mass,
        r"$M_{\odot}$",
        time_delay,
    )
)

plt.suptitle(r"Mismatch Between RP Templates & a Lensed Source as a Function of $I$")

plt.show()

# %%
I_ep_min_theta_tilde_arr = np.array(
    [mismatch_I_dict[I]["ep_min_theta_tilde"] for I in I_arr]
)

plt.plot(I_arr, I_ep_min_theta_tilde_arr, label=r"$\~{\theta}_{\rm best}$")
plt.xlabel(r"$I$")
plt.ylabel(r"$\~{\theta}_{\rm best}$")

plt.title(
    r"$\theta_S$ = {:.3g}, $\phi_S$ = {:.3g}, $\theta_J$ = {:.3g}, $\phi_J$ = {:.3g}, {} = {:.3g} {}, $\Delta t_d$ = {:.3g} s".format(
        lens_params["theta_S"],
        lens_params["phi_S"],
        lens_params["theta_J"],
        lens_params["phi_J"],
        r"$\mathcal{M}_{\text{s}}$",
        lens_params["mcz"] / solar_mass,
        r"$M_{\odot}$",
        time_delay,
    )
)

plt.suptitle(r"Mismatch Between RP Templates & a Lensed Source as a Function of $I$")

plt.show()

# %% [markdown]
# # waveform comparison

# %%
lens_params, RP_params, NP_params = set_to_params(
    lens_params_1, RP_params_1, NP_params_1
)

MLz_arr = np.linspace(400, 4600, 30)
Deltatd_ep_min_arr = np.array(
    [mismatch_Deltatd_dict[Delta_td]["ep_min"] for Delta_td in Delta_td_arr]
)

for i in range(len(MLz_arr)):
    lens_params, RP_params = set_to_params(lens_params_1, RP_params_1)
    lens_params["MLz"] = MLz_arr[i] * solar_mass
    RP_params["omega_tilde"] = mismatch_Deltatd_dict[Delta_td_arr[i]][
        "ep_min_omega_tilde"
    ]
    RP_params["theta_tilde"] = mismatch_Deltatd_dict[Delta_td_arr[i]][
        "ep_min_theta_tilde"
    ]
    RP_params["gamma_P"] = mismatch_Deltatd_dict[Delta_td_arr[i]]["ep_min_gammaP"]

    plot_waveform_comparison(RP_params, lens_params, get_updated_mismatch_results=True)
    plt.show()
# Out:
# idx = -2.2698e-09, phi = -3.98978e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = 1.94404e-09, phi = 2.05009e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -3.77877e-09, phi = 1.15953e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = 1.47405e-08, phi = -5.49066e-09, both should be ~0 if get_updated_mismatch_results is True
# idx = -9.38672e-09, phi = 7.92471e-09, both should be ~0 if get_updated_mismatch_results is True
# idx = -3.09089e-09, phi = 1.76909e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -7.45377e-09, phi = 4.21967e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -1.95909e-09, phi = 3.21276e-09, both should be ~0 if get_updated_mismatch_results is True
# idx = -1.40903e-08, phi = 5.50417e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = 2.17989e-08, phi = -4.63113e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = 3.7995e-09, phi = 1.92596e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -1.35783e-08, phi = 2.57646e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = 2.36862e-08, phi = 2.32791e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -2.30361e-08, phi = 5.80595e-09, both should be ~0 if get_updated_mismatch_results is True
# idx = 1.1378e-08, phi = -2.11034e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -1.87352e-09, phi = -3.24494e-09, both should be ~0 if get_updated_mismatch_results is True
# idx = 1.54766e-08, phi = -3.04758e-09, both should be ~0 if get_updated_mismatch_results is True
# idx = 7.68365e-09, phi = -1.5534e-11, both should be ~0 if get_updated_mismatch_results is True
# idx = -3.07173e-08, phi = 2.14423e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -1.0699e-10, phi = 5.97055e-09, both should be ~0 if get_updated_mismatch_results is True
# idx = 1.76888e-08, phi = -1.65512e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -6.48524e-09, phi = 1.15518e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -3.26076e-09, phi = -1.4963e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -3.93275e-09, phi = -9.86118e-13, both should be ~0 if get_updated_mismatch_results is True
# idx = -2.22575e-09, phi = 3.1859e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = 1.63683e-08, phi = -1.02626e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = 3.63099e-09, phi = 1.68588e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = -2.09195e-08, phi = 1.58973e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = 5.11862e-09, phi = 1.38851e-08, both should be ~0 if get_updated_mismatch_results is True
# idx = 5.07546e-09, phi = -1.57615e-08, both should be ~0 if get_updated_mismatch_results is True
